# %% [markdown]
# <a href="https://colab.research.google.com/github/Abhii009/Learn-Python/blob/main/Day3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("abhishek")
# Out:
# abhishek

# %%
#if
num1 = 10
if num1 > 2 :
  print ("num1 =", num1)
print ("if end")
# Out:
# num1 = 10
# if end

# %%
#if else
num1 = 20
num2 = 10
if num1 <= num2 :
  print ("if part run")
else:
    print ("else part run")
# Out:
# else part run

# %%
#if elif else
num1 = int(input("enter the number"))
num2 = 20
num3 = 30
if num1 > num2 :
  print ("if part run")
elif num1 > num3 :
  print ("elif part run")
else:
  print ("else part run")
# Out:
# enter the number40
# if part run

# %%
#list
l = [10,20,30]
#positive indxing
print (l[0])
print (l[1])
print (l[2])
#negative indexing
print (l[-1])
print (l[-2])
print (l[-3])
#mutable
l[0] = 100
print (l)
# Out:
# 10
# 20
# 30
# 30
# 20
# 10
# [100, 20, 30]

# %%
#dictnary
d = {"name": "Abhishek"}
print (d)
print(d['name'])
print (d.get('name'))
# Out:
# {'name': 'Abhishek'}
# Abhishek
# Abhishek

# %%
#example
d= {"full name" : "Abhishek form kota"}
print (d)
print (d['full name'])
# Out:
# {'full name': 'Abhishek form kota'}
# Abhishek form kota

# %%
d ={"age":"20", "name": "Abhishek"}
print (d['age'])
print (d['name'])
# Out:
# 20
# Abhishek

# %%
d = {"users": ["Abhishek", "Rahul"]}
print(d["users"])
print(d['users'][0])
print(d['users'][1])
# Out:
# ['Abhishek', 'Rahul']
# Abhishek
# Rahul

# %%
d = {"USERS": [{"message": "Hello"},
               {"name": "Rahul"}]}
print(d["USERS"][0]["message"])   # Hello
print(d["USERS"][1]["name"])      # Rahul
# Out:
# Hello
# Rahul

# %%
d = {
    "USERS": [
        {"name": "Abhishek", "message": "Hello"},
        {"name": "Rahul"},
        {"age": "21"},{"Roll no.": "23EACCA005"}]}

print(d["USERS"][0]["name"])      # Abhishek
print(d["USERS"][0]["message"])   # Hello
print(d["USERS"][1]["name"])      # Rahul
print(d["USERS"][2]["age"])       #age
print (d["USERS"][3]["Roll no."])  #Roll no.
# Out:
# Abhishek
# Hello
# Rahul
# 21
# 23EACCA005
